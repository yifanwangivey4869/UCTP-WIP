# %% [markdown]
# # UCTP for HBA1

# %%
import gurobipy as gp
from gurobipy import GRB
import datetime

# Initialize the model
model = gp.Model("University Course Timetabling")

# %% [markdown]
# ## Define Sets and Parameters

# %% [markdown]
# Sections

# %%
sections = list(range(1, 11))  # Sections 1 to 10

# %% [markdown]
# Dates and Periods

# %%
# Excluded dates
excluded_dates = [
    datetime.date(2024, 9, 30),
    datetime.date(2024, 10, 4),
    *[datetime.date(2024, 10, d) for d in range(14, 19)],  # October 14-18
    *[datetime.date(2024, 10, d) for d in range(22, 26)],  # October 22-25
    datetime.date(2024, 11, 21),
    datetime.date(2024, 11, 22),
    # Additional dates to exclude
    datetime.date(2024, 10, 30),
    datetime.date(2024, 10, 31),
    datetime.date(2024, 11, 1),
    datetime.date(2024, 12, 2)
]

# %%
# Generate dates from Sep 9 to Dec 6, excluding weekends
start_date = datetime.date(2024, 9, 9)
end_date = datetime.date(2024, 12, 6)
delta = datetime.timedelta(days=1)

dates = []
current_date = start_date
while current_date <= end_date:
    if (current_date.weekday() < 5 and
            current_date not in excluded_dates):
        dates.append(current_date)
    current_date += delta

periods = [1, 2, 3]  # Periods per day

# %%
# Define unavailable periods on specific dates
unavailable_periods = {
    datetime.date(2024, 9, 25): [3],
    datetime.date(2024, 11, 14): [2],
    datetime.date(2024, 11, 18): [3],
    datetime.date(2024, 11, 20): [3]
}

# %% [markdown]
# Courses and Required Sessions

# %%
# Courses and sessions
# Need to double-check is the number into optimization? For example, CME is removed since they are fixed.
courses = {
    'Communications': 25,
    'Finance': 25,
    'LPO': 25,
    'DMA': 24,
    'FinFun': 25,
    'SH': 2
}

# %% [markdown]
# Faculty

# %%
# Courses with faculty constraints
courses_with_faculty_constraints = ['Communications', 'Finance', 'LPO', 'DMA', 'FinFun']
courses_without_faculty_constraints = ['SH']

# Create faculties for each course
faculties_per_course = {}
faculty_sections_per_course = {}

for course in courses_with_faculty_constraints:
    faculties = [f'{course}_Faculty{i}' for i in range(1, 6)]
    faculties_per_course[course] = faculties
    # Assign sections to faculties
    faculty_sections = {}
    for idx, faculty in enumerate(faculties):
        sections_assigned = [idx * 2 + 1, idx * 2 + 2] 
        faculty_sections[faculty] = sections_assigned
    faculty_sections_per_course[course] = faculty_sections

# %% [markdown]
# ## Define Decision Variables

# %%
x = model.addVars(
    sections,
    dates,
    periods,
    courses.keys(),
    vtype=GRB.BINARY,
    name="x"
)

# %% [markdown]
# ## Objective Function

# %%
model.modelSense = GRB.MINIMIZE
model.setObjective(0)

# %% [markdown]
# ## Constraints

# %% [markdown]
# Each Course's Sessions Must Be Scheduled

# %%
for s in sections:
    for c, sessions_required in courses.items():
        model.addConstr(
            gp.quicksum(x[s, d, p, c] for d in dates for p in periods) == sessions_required,
            name=f"SessionRequirement_s{s}_c{c}"
        )

# %% [markdown]
# No Overlapping Sessions for a Section

# %%
for s in sections:
    for d in dates:
        for p in periods:
            model.addConstr(
                gp.quicksum(x[s, d, p, c] for c in courses.keys()) <= 1,
                name=f"NoOverlap_s{s}_d{d}_p{p}"
            )

# %% [markdown]
# Faculty availability constraints across courses (excluding CME and SH)

# %%
# Faculty availability constraints per course
for course in courses_with_faculty_constraints:
    faculties = faculties_per_course[course]
    faculty_sections = faculty_sections_per_course[course]
    for faculty in faculties:
        assigned_sections = faculty_sections[faculty]
        for d in dates:
            for p in periods:
                model.addConstr(
                    gp.quicksum(
                        x[s, d, p, course]
                        for s in assigned_sections
                    ) <= 1,
                    name=f"FacultyNoOverlap_{course}_{faculty}_d{d}_p{p}"
                )

# %% [markdown]
# Constraints to prevent scheduling during unavailable periods

# %%
# Constraints to prevent scheduling during unavailable periods
for d, periods_unavailable in unavailable_periods.items():
    if d in dates: 
        for p in periods_unavailable:
            for s in sections:
                for c in courses.keys():
                    model.addConstr(
                        x[s, d, p, c] == 0,
                        name=f"UnavailablePeriod_s{s}_d{d}_p{p}_c{c}"
                    )

# %% [markdown]
# CME sessions are fixed

# %%
# CME sessions are fixed; prevent other courses from being scheduled at those times
# Define CME sessions for each group
cme_sessions = {
    'Group1': {
        'sections': [1, 2, 3],
        'sessions': [
            (datetime.date(2024, 9, 11), 3),
            (datetime.date(2024, 9, 23), 3),
            (datetime.date(2024, 10, 28), 3),
            (datetime.date(2024, 11, 15), 1),
            (datetime.date(2024, 11, 28), 3)
        ]
    },
    'Group2': {
        'sections': [4, 5, 6],
        'sessions': [
            (datetime.date(2024, 9, 9), 3),
            (datetime.date(2024, 9, 23), 1),
            (datetime.date(2024, 10, 28), 1),
            (datetime.date(2024, 11, 13), 3),
            (datetime.date(2024, 11, 27), 3)
        ]
    },
    'Group3': {
        'sections': [7, 8, 9, 10],
        'sessions': [
            (datetime.date(2024, 9, 11), 1),
            (datetime.date(2024, 9, 20), 1),
            (datetime.date(2024, 10, 29), 3),
            (datetime.date(2024, 11, 15), 3),
            (datetime.date(2024, 11, 26), 1)
        ]
    }
}

# %%
# Constraints to prevent scheduling other courses during CME sessions
for group_info in cme_sessions.values():
    sections_in_group = group_info['sections']
    for session_date, session_period in group_info['sessions']:
        if session_date in dates and session_period in periods:
            for s in sections_in_group:
                for c in courses.keys():  # All other courses
                    model.addConstr(
                        x[s, session_date, session_period, c] == 0,
                        name=f"CME_Overlap_s{s}_d{session_date}_p{session_period}_c{c}"
                    )

# %% [markdown]
# SH time and no overlapping constraints

# %%
sh1_dates = [d for d in dates if d < datetime.date(2024, 9, 23)]

# Define dates for SH2 (October 28 or October 29)
sh2_dates = [d for d in dates if d in [datetime.date(2024, 10, 28), datetime.date(2024, 10, 29)]]

# Enforce SH1 scheduling constraints
for s in sections:
    model.addConstr(
        gp.quicksum(x[s, d, p, 'SH'] for d in sh1_dates for p in periods) == 1,
        name=f"SH1_Scheduling_s{s}"
    )

# Enforce SH2 scheduling constraints
for s in sections:
    model.addConstr(
        gp.quicksum(x[s, d, p, 'SH'] for d in sh2_dates for p in periods) == 1,
        name=f"SH2_Scheduling_s{s}"
    )

# %%
# Define overlap constraints
overlap_constraints = [
    {
        'sh_sections': [1],
        'other_sections': [1, 2],
        'other_course': 'DMA'
    },
    {
        'sh_sections': [5, 6],
        'other_sections': [5, 6],
        'other_course': 'Finance'
    },
    {
        'sh_sections': [7, 8],
        'other_sections': [7, 8],
        'other_course': 'FinFun'
    },
    {
        'sh_sections': [9, 10],
        'other_sections': [9, 10],
        'other_course': 'LPO'
    }
]

# Add overlap constraints to the model
for oc in overlap_constraints:
    sh_sections = oc['sh_sections']
    other_sections = oc['other_sections']
    other_course = oc['other_course']
    for s in sh_sections:
        for d in dates:
            for p in periods:
                model.addConstr(
                    x[s, d, p, 'SH'] + gp.quicksum(x[os, d, p, other_course] for os in other_sections) <= 1,
                    name=f"Overlap_SH_{s}_{other_course}_{d}_{p}"
                )

# %% [markdown]
# ## Solve the Model

# %%
# Optimize the model
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 6668 rows, 8640 columns and 28404 nonzeros
# Model fingerprint: 0x8ed61d42
# Variable types: 0 continuous, 8640 integer (8640 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 20 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%

# %% [markdown]
# Display the Schedule

# %%
# Retrieve and display the schedule
if model.status == GRB.OPTIMAL:
    schedule = {}
    for s in sections:
        schedule[s] = []
        for d in dates:
            for p in periods:
                for c in courses.keys():
                    if x[s, d, p, c].X > 0.5:
                        schedule[s].append({
                            'date': d,
                            'period': p,
                            'course': c
                        })
    # Print the schedule for each section
    for s in sections:
        print(f"\nSchedule for Section {s}:")
        # Include CME sessions in the schedule
        cme_sessions_for_section = []
        for group_info in cme_sessions.values():
            if s in group_info['sections']:
                cme_sessions_for_section.extend([
                    {'date': session_date, 'period': session_period, 'course': 'CME'}
                    for session_date, session_period in group_info['sessions']
                ])
        # Combine scheduled sessions and CME sessions
        combined_schedule = schedule[s] + cme_sessions_for_section
        # Sort combined schedule
        combined_schedule.sort(key=lambda x: (x['date'], x['period']))
        for entry in combined_schedule:
            print(f"Date: {entry['date']}, Period: {entry['period']}, Course: {entry['course']}")
else:
    print("No feasible solution found.")
# Out:
# Schedule for Section 1:
# Date: 2024-09-09, Period: 1, Course: LPO
# Date: 2024-09-09, Period: 2, Course: FinFun
# Date: 2024-09-09, Period: 3, Course: Communications
# Date: 2024-09-10, Period: 1, Course: LPO
# Date: 2024-09-10, Period: 2, Course: FinFun
# Date: 2024-09-10, Period: 3, Course: DMA
# Date: 2024-09-11, Period: 1, Course: Communications
# Date: 2024-09-11, Period: 2, Course: Finance
# Date: 2024-09-11, Period: 3, Course: CME
# Date: 2024-09-12, Period: 1, Course: FinFun
# Date: 2024-09-12, Period: 2, Course: Finance
# Date: 2024-09-12, Period: 3, Course: DMA
# Date: 2024-09-13, Period: 1, Course: Communications
# Date: 2024-09-13, Period: 2, Course: SH
# Date: 2024-09-13, Period: 3, Course: DMA
# Date: 2024-09-16, Period: 1, Course: Finance
# Date: 2024-09-16, Period: 2, Course: LPO
# Date: 2024-09-16, Period: 3, Course: Communications
# Date: 2024-09-17, Period: 1, Course: DMA
# Date: 2024-09-17, Period: 2, Course: FinFun
# Date: 2024-09-17, Period: 3, Course: FinFun
# Date: 2024-09-18, Period: 1, Course: Communications
# Date: 2024-09-18, Period: 2, Course: FinFun
# Date: 2024-09-18, Period: 3, Course: Finance
# Date: 2024-09-19, Period: 1, Course: Finance
# Date: 2024-09-19, Period: 3, Course: Finance
# Date: 2024-09-20, Period: 1, Course: LPO
# Date: 2024-09-20, Period: 3, Course: Finance
# Date: 2024-09-23, Period: 1, Course: FinFun
# Date: 2024-09-23, Period: 2, Course: Communications
# Date: 2024-09-23, Period: 3, Course: CME
# Date: 2024-09-24, Period: 1, Course: Communications
# Date: 2024-09-24, Period: 2, Course: Finance
# Date: 2024-09-24, Period: 3, Course: LPO
# Date: 2024-09-25, Period: 1, Course: Communications
# Date: 2024-09-25, Period: 2, Course: Communications
# Date: 2024-09-26, Period: 1, Course: DMA
# Date: 2024-09-26, Period: 3, Course: LPO
# Date: 2024-09-27, Period: 1, Course: Finance
# Date: 2024-09-27, Period: 2, Course: FinFun
# Date: 2024-09-27, Period: 3, Course: FinFun
# Date: 2024-10-01, Period: 1, Course: FinFun
# Date: 2024-10-01, Period: 2, Course: FinFun
# Date: 2024-10-01, Period: 3, Course: LPO
# Date: 2024-10-02, Period: 1, Course: Finance
# Date: 2024-10-02, Period: 2, Course: LPO
# Date: 2024-10-02, Period: 3, Course: Finance
# Date: 2024-10-03, Period: 1, Course: LPO
# Date: 2024-10-03, Period: 2, Course: Communications
# Date: 2024-10-03, Period: 3, Course: Communications
# Date: 2024-10-07, Period: 1, Course: FinFun
# Date: 2024-10-07, Period: 2, Course: DMA
# Date: 2024-10-07, Period: 3, Course: Communications
# Date: 2024-10-08, Period: 1, Course: FinFun
# Date: 2024-10-08, Period: 2, Course: FinFun
# Date: 2024-10-08, Period: 3, Course: Communications
# Date: 2024-10-09, Period: 1, Course: Finance
# Date: 2024-10-09, Period: 2, Course: FinFun
# Date: 2024-10-09, Period: 3, Course: Finance
# Date: 2024-10-10, Period: 1, Course: Finance
# Date: 2024-10-10, Period: 3, Course: LPO
# Date: 2024-10-11, Period: 1, Course: LPO
# Date: 2024-10-11, Period: 2, Course: FinFun
# Date: 2024-10-11, Period: 3, Course: FinFun
# Date: 2024-10-21, Period: 1, Course: FinFun
# Date: 2024-10-21, Period: 2, Course: DMA
# Date: 2024-10-21, Period: 3, Course: LPO
# Date: 2024-10-28, Period: 2, Course: FinFun
# Date: 2024-10-28, Period: 3, Course: CME
# Date: 2024-10-29, Period: 1, Course: Communications
# Date: 2024-10-29, Period: 2, Course: DMA
# Date: 2024-10-29, Period: 3, Course: SH
# Date: 2024-11-04, Period: 2, Course: Communications
# Date: 2024-11-04, Period: 3, Course: Finance
# Date: 2024-11-05, Period: 1, Course: Communications
# Date: 2024-11-05, Period: 2, Course: Communications
# Date: 2024-11-05, Period: 3, Course: LPO
# Date: 2024-11-06, Period: 1, Course: LPO
# Date: 2024-11-06, Period: 2, Course: Finance
# Date: 2024-11-06, Period: 3, Course: DMA
# Date: 2024-11-07, Period: 1, Course: LPO
# Date: 2024-11-07, Period: 2, Course: LPO
# Date: 2024-11-07, Period: 3, Course: Communications
# Date: 2024-11-08, Period: 1, Course: Communications
# Date: 2024-11-08, Period: 2, Course: DMA
# Date: 2024-11-08, Period: 3, Course: DMA
# Date: 2024-11-11, Period: 1, Course: Finance
# Date: 2024-11-11, Period: 2, Course: FinFun
# Date: 2024-11-11, Period: 3, Course: FinFun
# Date: 2024-11-12, Period: 1, Course: FinFun
# Date: 2024-11-12, Period: 2, Course: FinFun
# Date: 2024-11-12, Period: 3, Course: FinFun
# Date: 2024-11-13, Period: 1, Course: DMA
# Date: 2024-11-13, Period: 2, Course: Finance
# Date: 2024-11-13, Period: 3, Course: DMA
# Date: 2024-11-14, Period: 1, Course: DMA
# Date: 2024-11-14, Period: 3, Course: LPO
# Date: 2024-11-15, Period: 1, Course: CME
# Date: 2024-11-15, Period: 2, Course: LPO
# Date: 2024-11-15, Period: 3, Course: DMA
# Date: 2024-11-18, Period: 1, Course: DMA
# Date: 2024-11-18, Period: 2, Course: Communications
# Date: 2024-11-19, Period: 1, Course: Communications
# Date: 2024-11-19, Period: 2, Course: Finance
# Date: 2024-11-19, Period: 3, Course: DMA
# Date: 2024-11-20, Period: 2, Course: DMA
# Date: 2024-11-25, Period: 1, Course: Finance
# Date: 2024-11-25, Period: 3, Course: LPO
# Date: 2024-11-26, Period: 1, Course: DMA
# Date: 2024-11-26, Period: 2, Course: DMA
# Date: 2024-11-26, Period: 3, Course: Finance
# Date: 2024-11-27, Period: 1, Course: DMA
# Date: 2024-11-27, Period: 2, Course: Finance
# Date: 2024-11-28, Period: 1, Course: FinFun
# Date: 2024-11-28, Period: 2, Course: LPO
# Date: 2024-11-28, Period: 3, Course: CME
# Date: 2024-11-29, Period: 1, Course: Finance
# Date: 2024-11-29, Period: 2, Course: Communications
# Date: 2024-11-29, Period: 3, Course: LPO
# Date: 2024-12-03, Period: 1, Course: LPO
# Date: 2024-12-03, Period: 2, Course: DMA
# Date: 2024-12-03, Period: 3, Course: Communications
# Date: 2024-12-04, Period: 1, Course: DMA
# Date: 2024-12-04, Period: 2, Course: LPO
# Date: 2024-12-04, Period: 3, Course: LPO
# Date: 2024-12-05, Period: 1, Course: Communications
# Date: 2024-12-05, Period: 2, Course: Finance
# Date: 2024-12-05, Period: 3, Course: Communications
# Date: 2024-12-06, Period: 1, Course: DMA
# Date: 2024-12-06, Period: 2, Course: Finance
# Date: 2024-12-06, Period: 3, Course: LPO
#
# Schedule for Section 2:
# Date: 2024-09-09, Period: 1, Course: Communications
# Date: 2024-09-09, Period: 2, Course: Finance
# Date: 2024-09-09, Period: 3, Course: LPO
# Date: 2024-09-10, Period: 1, Course: DMA
# Date: 2024-09-10, Period: 3, Course: Finance
# Date: 2024-09-11, Period: 1, Course: Finance
# Date: 2024-09-11, Period: 2, Course: FinFun
# Date: 2024-09-11, Period: 3, Course: CME
# Date: 2024-09-12, Period: 1, Course: Communications
# Date: 2024-09-12, Period: 2, Course: DMA
# Date: 2024-09-12, Period: 3, Course: Communications
# Date: 2024-09-13, Period: 2, Course: Communications
# Date: 2024-09-13, Period: 3, Course: LPO
# Date: 2024-09-16, Period: 1, Course: LPO
# Date: 2024-09-16, Period: 2, Course: FinFun
# Date: 2024-09-16, Period: 3, Course: Finance
# Date: 2024-09-17, Period: 1, Course: LPO
# Date: 2024-09-17, Period: 2, Course: Finance
# Date: 2024-09-17, Period: 3, Course: SH
# Date: 2024-09-18, Period: 1, Course: LPO
# Date: 2024-09-18, Period: 2, Course: Communications
# Date: 2024-09-18, Period: 3, Course: FinFun
# Date: 2024-09-19, Period: 1, Course: FinFun
# Date: 2024-09-19, Period: 2, Course: Communications
# Date: 2024-09-19, Period: 3, Course: LPO
# Date: 2024-09-20, Period: 1, Course: Communications
# Date: 2024-09-20, Period: 2, Course: LPO
# Date: 2024-09-20, Period: 3, Course: FinFun
# Date: 2024-09-23, Period: 1, Course: Communications
# Date: 2024-09-23, Period: 2, Course: Finance
# Date: 2024-09-23, Period: 3, Course: CME
# Date: 2024-09-24, Period: 1, Course: DMA
# Date: 2024-09-24, Period: 2, Course: DMA
# Date: 2024-09-24, Period: 3, Course: FinFun
# Date: 2024-09-25, Period: 1, Course: Finance
# Date: 2024-09-25, Period: 2, Course: FinFun
# Date: 2024-09-26, Period: 1, Course: Finance
# Date: 2024-09-26, Period: 2, Course: Finance
# Date: 2024-09-26, Period: 3, Course: DMA
# Date: 2024-09-27, Period: 1, Course: Communications
# Date: 2024-09-27, Period: 2, Course: LPO
# Date: 2024-09-27, Period: 3, Course: DMA
# Date: 2024-10-01, Period: 1, Course: Finance
# Date: 2024-10-01, Period: 2, Course: Communications
# Date: 2024-10-01, Period: 3, Course: DMA
# Date: 2024-10-02, Period: 2, Course: DMA
# Date: 2024-10-02, Period: 3, Course: FinFun
# Date: 2024-10-03, Period: 1, Course: DMA
# Date: 2024-10-03, Period: 2, Course: LPO
# Date: 2024-10-03, Period: 3, Course: Finance
# Date: 2024-10-07, Period: 1, Course: Finance
# Date: 2024-10-07, Period: 2, Course: LPO
# Date: 2024-10-07, Period: 3, Course: Finance
# Date: 2024-10-08, Period: 1, Course: Finance
# Date: 2024-10-08, Period: 2, Course: Communications
# Date: 2024-10-09, Period: 1, Course: DMA
# Date: 2024-10-09, Period: 3, Course: FinFun
# Date: 2024-10-10, Period: 1, Course: DMA
# Date: 2024-10-10, Period: 2, Course: Communications
# Date: 2024-10-10, Period: 3, Course: DMA
# Date: 2024-10-11, Period: 1, Course: FinFun
# Date: 2024-10-11, Period: 3, Course: Communications
# Date: 2024-10-21, Period: 1, Course: Finance
# Date: 2024-10-21, Period: 2, Course: LPO
# Date: 2024-10-21, Period: 3, Course: FinFun
# Date: 2024-10-28, Period: 1, Course: FinFun
# Date: 2024-10-28, Period: 2, Course: Communications
# Date: 2024-10-28, Period: 3, Course: CME
# Date: 2024-10-29, Period: 1, Course: LPO
# Date: 2024-10-29, Period: 2, Course: SH
# Date: 2024-11-04, Period: 1, Course: FinFun
# Date: 2024-11-04, Period: 2, Course: LPO
# Date: 2024-11-04, Period: 3, Course: DMA
# Date: 2024-11-05, Period: 1, Course: LPO
# Date: 2024-11-05, Period: 2, Course: DMA
# Date: 2024-11-05, Period: 3, Course: Communications
# Date: 2024-11-06, Period: 1, Course: DMA
# Date: 2024-11-06, Period: 2, Course: LPO
# Date: 2024-11-06, Period: 3, Course: Communications
# Date: 2024-11-07, Period: 1, Course: FinFun
# Date: 2024-11-07, Period: 2, Course: FinFun
# Date: 2024-11-07, Period: 3, Course: Finance
# Date: 2024-11-08, Period: 1, Course: DMA
# Date: 2024-11-08, Period: 2, Course: FinFun
# Date: 2024-11-08, Period: 3, Course: LPO
# Date: 2024-11-11, Period: 1, Course: FinFun
# Date: 2024-11-11, Period: 3, Course: Communications
# Date: 2024-11-12, Period: 2, Course: DMA
# Date: 2024-11-12, Period: 3, Course: LPO
# Date: 2024-11-13, Period: 1, Course: FinFun
# Date: 2024-11-13, Period: 2, Course: Communications
# Date: 2024-11-13, Period: 3, Course: FinFun
# Date: 2024-11-14, Period: 1, Course: Communications
# Date: 2024-11-14, Period: 3, Course: Finance
# Date: 2024-11-15, Period: 1, Course: CME
# Date: 2024-11-15, Period: 2, Course: DMA
# Date: 2024-11-15, Period: 3, Course: Finance
# Date: 2024-11-18, Period: 1, Course: LPO
# Date: 2024-11-18, Period: 2, Course: Finance
# Date: 2024-11-19, Period: 1, Course: DMA
# Date: 2024-11-19, Period: 2, Course: LPO
# Date: 2024-11-19, Period: 3, Course: Finance
# Date: 2024-11-20, Period: 1, Course: FinFun
# Date: 2024-11-20, Period: 2, Course: Finance
# Date: 2024-11-25, Period: 1, Course: LPO
# Date: 2024-11-25, Period: 2, Course: Finance
# Date: 2024-11-25, Period: 3, Course: Finance
# Date: 2024-11-26, Period: 1, Course: LPO
# Date: 2024-11-26, Period: 2, Course: Communications
# Date: 2024-11-26, Period: 3, Course: LPO
# Date: 2024-11-27, Period: 1, Course: Communications
# Date: 2024-11-27, Period: 2, Course: FinFun
# Date: 2024-11-27, Period: 3, Course: Communications
# Date: 2024-11-28, Period: 1, Course: Communications
# Date: 2024-11-28, Period: 2, Course: Communications
# Date: 2024-11-28, Period: 3, Course: CME
# Date: 2024-11-29, Period: 1, Course: FinFun
# Date: 2024-11-29, Period: 2, Course: Finance
# Date: 2024-11-29, Period: 3, Course: DMA
# Date: 2024-12-03, Period: 1, Course: DMA
# Date: 2024-12-03, Period: 2, Course: Communications
# Date: 2024-12-03, Period: 3, Course: FinFun
# Date: 2024-12-04, Period: 1, Course: Finance
# Date: 2024-12-04, Period: 2, Course: DMA
# Date: 2024-12-04, Period: 3, Course: DMA
# Date: 2024-12-05, Period: 1, Course: LPO
# Date: 2024-12-05, Period: 2, Course: LPO
# Date: 2024-12-05, Period: 3, Course: LPO
# Date: 2024-12-06, Period: 1, Course: FinFun
# Date: 2024-12-06, Period: 2, Course: FinFun
# Date: 2024-12-06, Period: 3, Course: DMA
#
# Schedule for Section 3:
# Date: 2024-09-09, Period: 1, Course: FinFun
# Date: 2024-09-09, Period: 2, Course: Communications
# Date: 2024-09-09, Period: 3, Course: Communications
# Date: 2024-09-10, Period: 1, Course: DMA
# Date: 2024-09-10, Period: 2, Course: Finance
# Date: 2024-09-10, Period: 3, Course: LPO
# Date: 2024-09-11, Period: 1, Course: DMA
# Date: 2024-09-11, Period: 2, Course: LPO
# Date: 2024-09-11, Period: 3, Course: CME
# Date: 2024-09-12, Period: 1, Course: FinFun
# Date: 2024-09-12, Period: 2, Course: Finance
# Date: 2024-09-12, Period: 3, Course: FinFun
# Date: 2024-09-13, Period: 2, Course: Communications
# Date: 2024-09-13, Period: 3, Course: DMA
# Date: 2024-09-16, Period: 1, Course: SH
# Date: 2024-09-16, Period: 3, Course: Communications
# Date: 2024-09-17, Period: 1, Course: DMA
# Date: 2024-09-17, Period: 2, Course: FinFun
# Date: 2024-09-17, Period: 3, Course: LPO
# Date: 2024-09-18, Period: 1, Course: DMA
# Date: 2024-09-18, Period: 2, Course: LPO
# Date: 2024-09-18, Period: 3, Course: FinFun
# Date: 2024-09-19, Period: 1, Course: LPO
# Date: 2024-09-19, Period: 2, Course: LPO
# Date: 2024-09-19, Period: 3, Course: FinFun
# Date: 2024-09-20, Period: 1, Course: DMA
# Date: 2024-09-20, Period: 2, Course: DMA
# Date: 2024-09-20, Period: 3, Course: Finance
# Date: 2024-09-23, Period: 1, Course: Finance
# Date: 2024-09-23, Period: 2, Course: DMA
# Date: 2024-09-23, Period: 3, Course: CME
# Date: 2024-09-24, Period: 1, Course: LPO
# Date: 2024-09-24, Period: 3, Course: Communications
# Date: 2024-09-25, Period: 1, Course: Communications
# Date: 2024-09-25, Period: 2, Course: LPO
# Date: 2024-09-26, Period: 1, Course: LPO
# Date: 2024-09-26, Period: 2, Course: DMA
# Date: 2024-09-26, Period: 3, Course: DMA
# Date: 2024-09-27, Period: 1, Course: LPO
# Date: 2024-09-27, Period: 2, Course: DMA
# Date: 2024-09-27, Period: 3, Course: Communications
# Date: 2024-10-01, Period: 1, Course: LPO
# Date: 2024-10-01, Period: 2, Course: Finance
# Date: 2024-10-02, Period: 1, Course: Finance
# Date: 2024-10-02, Period: 2, Course: Finance
# Date: 2024-10-02, Period: 3, Course: DMA
# Date: 2024-10-03, Period: 1, Course: Communications
# Date: 2024-10-03, Period: 2, Course: DMA
# Date: 2024-10-03, Period: 3, Course: DMA
# Date: 2024-10-07, Period: 1, Course: FinFun
# Date: 2024-10-07, Period: 2, Course: Communications
# Date: 2024-10-07, Period: 3, Course: DMA
# Date: 2024-10-08, Period: 1, Course: Finance
# Date: 2024-10-08, Period: 2, Course: LPO
# Date: 2024-10-08, Period: 3, Course: Finance
# Date: 2024-10-09, Period: 1, Course: Finance
# Date: 2024-10-09, Period: 2, Course: DMA
# Date: 2024-10-09, Period: 3, Course: FinFun
# Date: 2024-10-10, Period: 1, Course: DMA
# Date: 2024-10-10, Period: 2, Course: Communications
# Date: 2024-10-10, Period: 3, Course: Communications
# Date: 2024-10-11, Period: 1, Course: Communications
# Date: 2024-10-11, Period: 2, Course: Communications
# Date: 2024-10-11, Period: 3, Course: LPO
# Date: 2024-10-21, Period: 1, Course: FinFun
# Date: 2024-10-21, Period: 2, Course: DMA
# Date: 2024-10-21, Period: 3, Course: Finance
# Date: 2024-10-28, Period: 1, Course: SH
# Date: 2024-10-28, Period: 2, Course: FinFun
# Date: 2024-10-28, Period: 3, Course: CME
# Date: 2024-10-29, Period: 1, Course: LPO
# Date: 2024-10-29, Period: 2, Course: FinFun
# Date: 2024-10-29, Period: 3, Course: Finance
# Date: 2024-11-04, Period: 1, Course: DMA
# Date: 2024-11-04, Period: 2, Course: LPO
# Date: 2024-11-04, Period: 3, Course: Communications
# Date: 2024-11-05, Period: 1, Course: Communications
# Date: 2024-11-05, Period: 2, Course: FinFun
# Date: 2024-11-05, Period: 3, Course: Finance
# Date: 2024-11-06, Period: 3, Course: FinFun
# Date: 2024-11-07, Period: 1, Course: LPO
# Date: 2024-11-07, Period: 2, Course: Finance
# Date: 2024-11-07, Period: 3, Course: LPO
# Date: 2024-11-08, Period: 1, Course: FinFun
# Date: 2024-11-08, Period: 2, Course: FinFun
# Date: 2024-11-08, Period: 3, Course: FinFun
# Date: 2024-11-11, Period: 1, Course: FinFun
# Date: 2024-11-11, Period: 2, Course: DMA
# Date: 2024-11-11, Period: 3, Course: Communications
# Date: 2024-11-12, Period: 1, Course: FinFun
# Date: 2024-11-12, Period: 2, Course: FinFun
# Date: 2024-11-12, Period: 3, Course: LPO
# Date: 2024-11-13, Period: 1, Course: Communications
# Date: 2024-11-13, Period: 2, Course: DMA
# Date: 2024-11-13, Period: 3, Course: LPO
# Date: 2024-11-14, Period: 1, Course: FinFun
# Date: 2024-11-14, Period: 3, Course: FinFun
# Date: 2024-11-15, Period: 1, Course: CME
# Date: 2024-11-15, Period: 2, Course: FinFun
# Date: 2024-11-15, Period: 3, Course: LPO
# Date: 2024-11-18, Period: 2, Course: Communications
# Date: 2024-11-19, Period: 1, Course: FinFun
# Date: 2024-11-19, Period: 2, Course: DMA
# Date: 2024-11-19, Period: 3, Course: Finance
# Date: 2024-11-20, Period: 1, Course: LPO
# Date: 2024-11-20, Period: 2, Course: DMA
# Date: 2024-11-25, Period: 1, Course: Finance
# Date: 2024-11-25, Period: 2, Course: Communications
# Date: 2024-11-25, Period: 3, Course: Communications
# Date: 2024-11-26, Period: 1, Course: Finance
# Date: 2024-11-26, Period: 2, Course: Finance
# Date: 2024-11-27, Period: 1, Course: Communications
# Date: 2024-11-27, Period: 2, Course: Finance
# Date: 2024-11-27, Period: 3, Course: LPO
# Date: 2024-11-28, Period: 1, Course: Finance
# Date: 2024-11-28, Period: 2, Course: Finance
# Date: 2024-11-28, Period: 3, Course: CME
# Date: 2024-11-29, Period: 1, Course: FinFun
# Date: 2024-11-29, Period: 3, Course: Communications
# Date: 2024-12-03, Period: 1, Course: Finance
# Date: 2024-12-03, Period: 2, Course: LPO
# Date: 2024-12-03, Period: 3, Course: FinFun
# Date: 2024-12-04, Period: 1, Course: LPO
# Date: 2024-12-04, Period: 2, Course: Communications
# Date: 2024-12-04, Period: 3, Course: Finance
# Date: 2024-12-05, Period: 1, Course: DMA
# Date: 2024-12-05, Period: 2, Course: Finance
# Date: 2024-12-05, Period: 3, Course: Communications
# Date: 2024-12-06, Period: 1, Course: Communications
# Date: 2024-12-06, Period: 2, Course: Finance
# Date: 2024-12-06, Period: 3, Course: LPO
#
# Schedule for Section 4:
# Date: 2024-09-09, Period: 1, Course: Communications
# Date: 2024-09-09, Period: 2, Course: Finance
# Date: 2024-09-09, Period: 3, Course: CME
# Date: 2024-09-10, Period: 1, Course: FinFun
# Date: 2024-09-10, Period: 2, Course: DMA
# Date: 2024-09-10, Period: 3, Course: DMA
# Date: 2024-09-11, Period: 1, Course: LPO
# Date: 2024-09-11, Period: 2, Course: DMA
# Date: 2024-09-11, Period: 3, Course: Finance
# Date: 2024-09-12, Period: 1, Course: LPO
# Date: 2024-09-12, Period: 2, Course: Communications
# Date: 2024-09-13, Period: 1, Course: SH
# Date: 2024-09-13, Period: 2, Course: FinFun
# Date: 2024-09-13, Period: 3, Course: FinFun
# Date: 2024-09-16, Period: 1, Course: Communications
# Date: 2024-09-16, Period: 2, Course: DMA
# Date: 2024-09-16, Period: 3, Course: Finance
# Date: 2024-09-17, Period: 1, Course: Finance
# Date: 2024-09-17, Period: 2, Course: LPO
# Date: 2024-09-17, Period: 3, Course: Communications
# Date: 2024-09-18, Period: 1, Course: LPO
# Date: 2024-09-18, Period: 2, Course: DMA
# Date: 2024-09-18, Period: 3, Course: DMA
# Date: 2024-09-19, Period: 1, Course: Finance
# Date: 2024-09-19, Period: 2, Course: Communications
# Date: 2024-09-19, Period: 3, Course: LPO
# Date: 2024-09-20, Period: 1, Course: Communications
# Date: 2024-09-20, Period: 2, Course: Communications
# Date: 2024-09-20, Period: 3, Course: DMA
# Date: 2024-09-23, Period: 1, Course: CME
# Date: 2024-09-23, Period: 2, Course: LPO
# Date: 2024-09-23, Period: 3, Course: FinFun
# Date: 2024-09-24, Period: 1, Course: FinFun
# Date: 2024-09-24, Period: 2, Course: DMA
# Date: 2024-09-24, Period: 3, Course: DMA
# Date: 2024-09-25, Period: 1, Course: FinFun
# Date: 2024-09-25, Period: 2, Course: FinFun
# Date: 2024-09-26, Period: 2, Course: Communications
# Date: 2024-09-26, Period: 3, Course: LPO
# Date: 2024-09-27, Period: 1, Course: FinFun
# Date: 2024-09-27, Period: 2, Course: Finance
# Date: 2024-09-27, Period: 3, Course: LPO
# Date: 2024-10-01, Period: 1, Course: Communications
# Date: 2024-10-01, Period: 2, Course: Communications
# Date: 2024-10-01, Period: 3, Course: Communications
# Date: 2024-10-02, Period: 1, Course: FinFun
# Date: 2024-10-02, Period: 2, Course: LPO
# Date: 2024-10-02, Period: 3, Course: LPO
# Date: 2024-10-03, Period: 1, Course: Finance
# Date: 2024-10-03, Period: 2, Course: LPO
# Date: 2024-10-03, Period: 3, Course: Communications
# Date: 2024-10-07, Period: 1, Course: LPO
# Date: 2024-10-07, Period: 2, Course: DMA
# Date: 2024-10-07, Period: 3, Course: FinFun
# Date: 2024-10-08, Period: 1, Course: LPO
# Date: 2024-10-08, Period: 2, Course: DMA
# Date: 2024-10-08, Period: 3, Course: Communications
# Date: 2024-10-09, Period: 1, Course: DMA
# Date: 2024-10-09, Period: 2, Course: FinFun
# Date: 2024-10-09, Period: 3, Course: Finance
# Date: 2024-10-10, Period: 1, Course: FinFun
# Date: 2024-10-10, Period: 2, Course: FinFun
# Date: 2024-10-10, Period: 3, Course: LPO
# Date: 2024-10-11, Period: 1, Course: DMA
# Date: 2024-10-11, Period: 2, Course: LPO
# Date: 2024-10-11, Period: 3, Course: Finance
# Date: 2024-10-21, Period: 1, Course: Finance
# Date: 2024-10-21, Period: 2, Course: Finance
# Date: 2024-10-21, Period: 3, Course: FinFun
# Date: 2024-10-28, Period: 1, Course: CME
# Date: 2024-10-28, Period: 2, Course: Finance
# Date: 2024-10-28, Period: 3, Course: Finance
# Date: 2024-10-29, Period: 1, Course: SH
# Date: 2024-10-29, Period: 2, Course: Communications
# Date: 2024-10-29, Period: 3, Course: LPO
# Date: 2024-11-04, Period: 1, Course: FinFun
# Date: 2024-11-04, Period: 2, Course: Finance
# Date: 2024-11-04, Period: 3, Course: FinFun
# Date: 2024-11-05, Period: 1, Course: LPO
# Date: 2024-11-05, Period: 2, Course: Communications
# Date: 2024-11-05, Period: 3, Course: FinFun
# Date: 2024-11-06, Period: 1, Course: FinFun
# Date: 2024-11-06, Period: 2, Course: Communications
# Date: 2024-11-06, Period: 3, Course: Communications
# Date: 2024-11-07, Period: 1, Course: FinFun
# Date: 2024-11-07, Period: 2, Course: Communications
# Date: 2024-11-07, Period: 3, Course: Communications
# Date: 2024-11-08, Period: 1, Course: LPO
# Date: 2024-11-11, Period: 2, Course: Finance
# Date: 2024-11-11, Period: 3, Course: Finance
# Date: 2024-11-12, Period: 3, Course: Communications
# Date: 2024-11-13, Period: 1, Course: FinFun
# Date: 2024-11-13, Period: 2, Course: Communications
# Date: 2024-11-13, Period: 3, Course: CME
# Date: 2024-11-14, Period: 1, Course: LPO
# Date: 2024-11-14, Period: 3, Course: Finance
# Date: 2024-11-15, Period: 1, Course: Finance
# Date: 2024-11-15, Period: 3, Course: DMA
# Date: 2024-11-18, Period: 1, Course: DMA
# Date: 2024-11-18, Period: 2, Course: Finance
# Date: 2024-11-19, Period: 2, Course: LPO
# Date: 2024-11-19, Period: 3, Course: LPO
# Date: 2024-11-20, Period: 1, Course: DMA
# Date: 2024-11-20, Period: 2, Course: LPO
# Date: 2024-11-25, Period: 1, Course: DMA
# Date: 2024-11-25, Period: 2, Course: Finance
# Date: 2024-11-25, Period: 3, Course: DMA
# Date: 2024-11-26, Period: 1, Course: DMA
# Date: 2024-11-26, Period: 2, Course: Communications
# Date: 2024-11-26, Period: 3, Course: DMA
# Date: 2024-11-27, Period: 1, Course: Finance
# Date: 2024-11-27, Period: 2, Course: Communications
# Date: 2024-11-27, Period: 3, Course: CME
# Date: 2024-11-28, Period: 1, Course: FinFun
# Date: 2024-11-28, Period: 2, Course: DMA
# Date: 2024-11-28, Period: 3, Course: DMA
# Date: 2024-11-29, Period: 1, Course: DMA
# Date: 2024-11-29, Period: 2, Course: Finance
# Date: 2024-11-29, Period: 3, Course: DMA
# Date: 2024-12-03, Period: 1, Course: LPO
# Date: 2024-12-03, Period: 2, Course: Communications
# Date: 2024-12-03, Period: 3, Course: Communications
# Date: 2024-12-04, Period: 1, Course: Finance
# Date: 2024-12-04, Period: 2, Course: LPO
# Date: 2024-12-04, Period: 3, Course: LPO
# Date: 2024-12-05, Period: 1, Course: FinFun
# Date: 2024-12-05, Period: 2, Course: FinFun
# Date: 2024-12-05, Period: 3, Course: Finance
# Date: 2024-12-06, Period: 1, Course: Finance
# Date: 2024-12-06, Period: 2, Course: FinFun
# Date: 2024-12-06, Period: 3, Course: FinFun
#
# Schedule for Section 5:
# Date: 2024-09-09, Period: 1, Course: FinFun
# Date: 2024-09-09, Period: 2, Course: DMA
# Date: 2024-09-09, Period: 3, Course: CME
# Date: 2024-09-10, Period: 1, Course: Communications
# Date: 2024-09-10, Period: 2, Course: DMA
# Date: 2024-09-10, Period: 3, Course: Finance
# Date: 2024-09-11, Period: 1, Course: DMA
# Date: 2024-09-11, Period: 2, Course: Communications
# Date: 2024-09-11, Period: 3, Course: Communications
# Date: 2024-09-12, Period: 1, Course: LPO
# Date: 2024-09-12, Period: 2, Course: Finance
# Date: 2024-09-12, Period: 3, Course: DMA
# Date: 2024-09-13, Period: 1, Course: DMA
# Date: 2024-09-13, Period: 3, Course: LPO
# Date: 2024-09-16, Period: 1, Course: Communications
# Date: 2024-09-16, Period: 2, Course: Finance
# Date: 2024-09-16, Period: 3, Course: Communications
# Date: 2024-09-17, Period: 1, Course: Finance
# Date: 2024-09-17, Period: 2, Course: DMA
# Date: 2024-09-17, Period: 3, Course: SH
# Date: 2024-09-18, Period: 1, Course: DMA
# Date: 2024-09-18, Period: 3, Course: Finance
# Date: 2024-09-19, Period: 1, Course: Communications
# Date: 2024-09-19, Period: 2, Course: LPO
# Date: 2024-09-19, Period: 3, Course: DMA
# Date: 2024-09-20, Period: 1, Course: Finance
# Date: 2024-09-20, Period: 3, Course: Finance
# Date: 2024-09-23, Period: 1, Course: CME
# Date: 2024-09-23, Period: 2, Course: LPO
# Date: 2024-09-23, Period: 3, Course: Communications
# Date: 2024-09-24, Period: 1, Course: DMA
# Date: 2024-09-24, Period: 2, Course: DMA
# Date: 2024-09-24, Period: 3, Course: DMA
# Date: 2024-09-25, Period: 1, Course: DMA
# Date: 2024-09-25, Period: 2, Course: Finance
# Date: 2024-09-26, Period: 1, Course: FinFun
# Date: 2024-09-26, Period: 2, Course: LPO
# Date: 2024-09-26, Period: 3, Course: FinFun
# Date: 2024-09-27, Period: 1, Course: Communications
# Date: 2024-09-27, Period: 2, Course: Finance
# Date: 2024-09-27, Period: 3, Course: FinFun
# Date: 2024-10-01, Period: 1, Course: FinFun
# Date: 2024-10-01, Period: 2, Course: FinFun
# Date: 2024-10-01, Period: 3, Course: FinFun
# Date: 2024-10-02, Period: 1, Course: DMA
# Date: 2024-10-02, Period: 2, Course: Communications
# Date: 2024-10-02, Period: 3, Course: DMA
# Date: 2024-10-03, Period: 1, Course: LPO
# Date: 2024-10-03, Period: 2, Course: Finance
# Date: 2024-10-03, Period: 3, Course: Finance
# Date: 2024-10-07, Period: 1, Course: Finance
# Date: 2024-10-07, Period: 2, Course: Communications
# Date: 2024-10-07, Period: 3, Course: Finance
# Date: 2024-10-08, Period: 1, Course: LPO
# Date: 2024-10-08, Period: 2, Course: Communications
# Date: 2024-10-08, Period: 3, Course: LPO
# Date: 2024-10-09, Period: 1, Course: LPO
# Date: 2024-10-09, Period: 2, Course: DMA
# Date: 2024-10-09, Period: 3, Course: FinFun
# Date: 2024-10-10, Period: 1, Course: Finance
# Date: 2024-10-10, Period: 2, Course: Finance
# Date: 2024-10-10, Period: 3, Course: Finance
# Date: 2024-10-11, Period: 1, Course: Communications
# Date: 2024-10-11, Period: 2, Course: Communications
# Date: 2024-10-11, Period: 3, Course: DMA
# Date: 2024-10-21, Period: 2, Course: LPO
# Date: 2024-10-21, Period: 3, Course: LPO
# Date: 2024-10-28, Period: 1, Course: CME
# Date: 2024-10-28, Period: 2, Course: FinFun
# Date: 2024-10-28, Period: 3, Course: LPO
# Date: 2024-10-29, Period: 1, Course: FinFun
# Date: 2024-10-29, Period: 2, Course: Communications
# Date: 2024-10-29, Period: 3, Course: SH
# Date: 2024-11-04, Period: 1, Course: FinFun
# Date: 2024-11-04, Period: 2, Course: Finance
# Date: 2024-11-04, Period: 3, Course: Finance
# Date: 2024-11-05, Period: 1, Course: LPO
# Date: 2024-11-05, Period: 2, Course: LPO
# Date: 2024-11-05, Period: 3, Course: Communications
# Date: 2024-11-06, Period: 1, Course: LPO
# Date: 2024-11-06, Period: 2, Course: FinFun
# Date: 2024-11-06, Period: 3, Course: Communications
# Date: 2024-11-07, Period: 1, Course: Communications
# Date: 2024-11-07, Period: 2, Course: LPO
# Date: 2024-11-08, Period: 1, Course: Finance
# Date: 2024-11-08, Period: 2, Course: DMA
# Date: 2024-11-08, Period: 3, Course: Finance
# Date: 2024-11-11, Period: 1, Course: FinFun
# Date: 2024-11-11, Period: 2, Course: FinFun
# Date: 2024-11-11, Period: 3, Course: Communications
# Date: 2024-11-12, Period: 1, Course: DMA
# Date: 2024-11-12, Period: 2, Course: FinFun
# Date: 2024-11-12, Period: 3, Course: Communications
# Date: 2024-11-13, Period: 1, Course: FinFun
# Date: 2024-11-13, Period: 2, Course: LPO
# Date: 2024-11-13, Period: 3, Course: CME
# Date: 2024-11-14, Period: 1, Course: FinFun
# Date: 2024-11-14, Period: 3, Course: DMA
# Date: 2024-11-15, Period: 1, Course: Communications
# Date: 2024-11-15, Period: 2, Course: FinFun
# Date: 2024-11-15, Period: 3, Course: DMA
# Date: 2024-11-18, Period: 1, Course: Finance
# Date: 2024-11-18, Period: 2, Course: FinFun
# Date: 2024-11-19, Period: 1, Course: FinFun
# Date: 2024-11-19, Period: 2, Course: Communications
# Date: 2024-11-19, Period: 3, Course: LPO
# Date: 2024-11-20, Period: 1, Course: Communications
# Date: 2024-11-20, Period: 2, Course: Communications
# Date: 2024-11-25, Period: 1, Course: DMA
# Date: 2024-11-25, Period: 2, Course: Finance
# Date: 2024-11-25, Period: 3, Course: DMA
# Date: 2024-11-26, Period: 1, Course: DMA
# Date: 2024-11-26, Period: 3, Course: LPO
# Date: 2024-11-27, Period: 1, Course: LPO
# Date: 2024-11-27, Period: 2, Course: FinFun
# Date: 2024-11-27, Period: 3, Course: CME
# Date: 2024-11-28, Period: 1, Course: LPO
# Date: 2024-11-28, Period: 2, Course: LPO
# Date: 2024-11-28, Period: 3, Course: Communications
# Date: 2024-11-29, Period: 1, Course: DMA
# Date: 2024-11-29, Period: 2, Course: LPO
# Date: 2024-12-03, Period: 1, Course: Finance
# Date: 2024-12-04, Period: 1, Course: FinFun
# Date: 2024-12-04, Period: 2, Course: FinFun
# Date: 2024-12-04, Period: 3, Course: Finance
# Date: 2024-12-05, Period: 1, Course: LPO
# Date: 2024-12-05, Period: 2, Course: Communications
# Date: 2024-12-05, Period: 3, Course: FinFun
# Date: 2024-12-06, Period: 1, Course: Finance
# Date: 2024-12-06, Period: 2, Course: LPO
# Date: 2024-12-06, Period: 3, Course: FinFun
#
# Schedule for Section 6:
# Date: 2024-09-09, Period: 1, Course: Finance
# Date: 2024-09-09, Period: 2, Course: FinFun
# Date: 2024-09-09, Period: 3, Course: CME
# Date: 2024-09-10, Period: 1, Course: FinFun
# Date: 2024-09-10, Period: 2, Course: FinFun
# Date: 2024-09-10, Period: 3, Course: DMA
# Date: 2024-09-11, Period: 2, Course: FinFun
# Date: 2024-09-11, Period: 3, Course: Finance
# Date: 2024-09-12, Period: 1, Course: Communications
# Date: 2024-09-12, Period: 2, Course: DMA
# Date: 2024-09-12, Period: 3, Course: LPO
# Date: 2024-09-13, Period: 1, Course: Communications
# Date: 2024-09-13, Period: 2, Course: LPO
# Date: 2024-09-13, Period: 3, Course: Finance
# Date: 2024-09-16, Period: 1, Course: SH
# Date: 2024-09-16, Period: 2, Course: DMA
# Date: 2024-09-16, Period: 3, Course: Finance
# Date: 2024-09-17, Period: 1, Course: FinFun
# Date: 2024-09-17, Period: 2, Course: LPO
# Date: 2024-09-17, Period: 3, Course: Communications
# Date: 2024-09-18, Period: 1, Course: LPO
# Date: 2024-09-18, Period: 2, Course: Finance
# Date: 2024-09-18, Period: 3, Course: DMA
# Date: 2024-09-19, Period: 1, Course: DMA
# Date: 2024-09-19, Period: 2, Course: Finance
# Date: 2024-09-19, Period: 3, Course: FinFun
# Date: 2024-09-20, Period: 1, Course: Communications
# Date: 2024-09-20, Period: 2, Course: FinFun
# Date: 2024-09-20, Period: 3, Course: Communications
# Date: 2024-09-23, Period: 1, Course: CME
# Date: 2024-09-23, Period: 2, Course: DMA
# Date: 2024-09-23, Period: 3, Course: LPO
# Date: 2024-09-24, Period: 1, Course: FinFun
# Date: 2024-09-24, Period: 2, Course: LPO
# Date: 2024-09-24, Period: 3, Course: FinFun
# Date: 2024-09-25, Period: 1, Course: LPO
# Date: 2024-09-25, Period: 2, Course: DMA
# Date: 2024-09-26, Period: 1, Course: DMA
# Date: 2024-09-26, Period: 2, Course: Communications
# Date: 2024-09-26, Period: 3, Course: Communications
# Date: 2024-09-27, Period: 1, Course: FinFun
# Date: 2024-09-27, Period: 3, Course: Finance
# Date: 2024-10-01, Period: 1, Course: LPO
# Date: 2024-10-01, Period: 2, Course: Communications
# Date: 2024-10-02, Period: 1, Course: FinFun
# Date: 2024-10-02, Period: 3, Course: Communications
# Date: 2024-10-03, Period: 1, Course: FinFun
# Date: 2024-10-03, Period: 2, Course: DMA
# Date: 2024-10-03, Period: 3, Course: LPO
# Date: 2024-10-07, Period: 1, Course: LPO
# Date: 2024-10-07, Period: 3, Course: FinFun
# Date: 2024-10-08, Period: 1, Course: FinFun
# Date: 2024-10-08, Period: 2, Course: DMA
# Date: 2024-10-08, Period: 3, Course: Finance
# Date: 2024-10-09, Period: 1, Course: FinFun
# Date: 2024-10-09, Period: 2, Course: Finance
# Date: 2024-10-09, Period: 3, Course: Communications
# Date: 2024-10-10, Period: 1, Course: FinFun
# Date: 2024-10-10, Period: 2, Course: LPO
# Date: 2024-10-10, Period: 3, Course: Communications
# Date: 2024-10-11, Period: 1, Course: Finance
# Date: 2024-10-11, Period: 2, Course: DMA
# Date: 2024-10-11, Period: 3, Course: Finance
# Date: 2024-10-21, Period: 1, Course: DMA
# Date: 2024-10-21, Period: 2, Course: Communications
# Date: 2024-10-21, Period: 3, Course: DMA
# Date: 2024-10-28, Period: 1, Course: CME
# Date: 2024-10-28, Period: 2, Course: SH
# Date: 2024-10-28, Period: 3, Course: DMA
# Date: 2024-10-29, Period: 1, Course: Communications
# Date: 2024-10-29, Period: 2, Course: LPO
# Date: 2024-11-04, Period: 1, Course: Finance
# Date: 2024-11-04, Period: 2, Course: FinFun
# Date: 2024-11-04, Period: 3, Course: FinFun
# Date: 2024-11-05, Period: 1, Course: Finance
# Date: 2024-11-05, Period: 2, Course: DMA
# Date: 2024-11-05, Period: 3, Course: LPO
# Date: 2024-11-06, Period: 1, Course: FinFun
# Date: 2024-11-06, Period: 2, Course: Finance
# Date: 2024-11-07, Period: 1, Course: Finance
# Date: 2024-11-07, Period: 2, Course: FinFun
# Date: 2024-11-07, Period: 3, Course: LPO
# Date: 2024-11-08, Period: 1, Course: Communications
# Date: 2024-11-08, Period: 2, Course: FinFun
# Date: 2024-11-08, Period: 3, Course: LPO
# Date: 2024-11-11, Period: 1, Course: Communications
# Date: 2024-11-11, Period: 3, Course: DMA
# Date: 2024-11-12, Period: 1, Course: FinFun
# Date: 2024-11-12, Period: 2, Course: Finance
# Date: 2024-11-12, Period: 3, Course: LPO
# Date: 2024-11-13, Period: 1, Course: Finance
# Date: 2024-11-13, Period: 2, Course: DMA
# Date: 2024-11-13, Period: 3, Course: CME
# Date: 2024-11-14, Period: 1, Course: DMA
# Date: 2024-11-14, Period: 3, Course: Communications
# Date: 2024-11-15, Period: 1, Course: DMA
# Date: 2024-11-15, Period: 2, Course: Communications
# Date: 2024-11-15, Period: 3, Course: LPO
# Date: 2024-11-18, Period: 1, Course: DMA
# Date: 2024-11-18, Period: 2, Course: Finance
# Date: 2024-11-19, Period: 1, Course: Finance
# Date: 2024-11-19, Period: 2, Course: LPO
# Date: 2024-11-19, Period: 3, Course: Finance
# Date: 2024-11-20, Period: 1, Course: LPO
# Date: 2024-11-20, Period: 2, Course: FinFun
# Date: 2024-11-25, Period: 1, Course: Communications
# Date: 2024-11-25, Period: 2, Course: LPO
# Date: 2024-11-25, Period: 3, Course: Finance
# Date: 2024-11-26, Period: 2, Course: Finance
# Date: 2024-11-26, Period: 3, Course: Communications
# Date: 2024-11-27, Period: 1, Course: DMA
# Date: 2024-11-27, Period: 2, Course: Communications
# Date: 2024-11-27, Period: 3, Course: CME
# Date: 2024-11-28, Period: 1, Course: Finance
# Date: 2024-11-28, Period: 2, Course: Communications
# Date: 2024-11-28, Period: 3, Course: Finance
# Date: 2024-11-29, Period: 1, Course: LPO
# Date: 2024-11-29, Period: 2, Course: FinFun
# Date: 2024-11-29, Period: 3, Course: LPO
# Date: 2024-12-03, Period: 1, Course: DMA
# Date: 2024-12-03, Period: 2, Course: LPO
# Date: 2024-12-03, Period: 3, Course: Communications
# Date: 2024-12-04, Period: 1, Course: Communications
# Date: 2024-12-04, Period: 2, Course: Communications
# Date: 2024-12-04, Period: 3, Course: LPO
# Date: 2024-12-05, Period: 1, Course: DMA
# Date: 2024-12-05, Period: 2, Course: FinFun
# Date: 2024-12-05, Period: 3, Course: DMA
# Date: 2024-12-06, Period: 1, Course: Communications
# Date: 2024-12-06, Period: 2, Course: Finance
# Date: 2024-12-06, Period: 3, Course: LPO
#
# Schedule for Section 7:
# Date: 2024-09-09, Period: 2, Course: DMA
# Date: 2024-09-09, Period: 3, Course: FinFun
# Date: 2024-09-10, Period: 1, Course: FinFun
# Date: 2024-09-10, Period: 2, Course: DMA
# Date: 2024-09-10, Period: 3, Course: LPO
# Date: 2024-09-11, Period: 1, Course: CME
# Date: 2024-09-11, Period: 3, Course: DMA
# Date: 2024-09-12, Period: 1, Course: FinFun
# Date: 2024-09-12, Period: 2, Course: Communications
# Date: 2024-09-12, Period: 3, Course: LPO
# Date: 2024-09-13, Period: 1, Course: DMA
# Date: 2024-09-13, Period: 2, Course: Communications
# Date: 2024-09-13, Period: 3, Course: FinFun
# Date: 2024-09-16, Period: 1, Course: LPO
# Date: 2024-09-16, Period: 2, Course: DMA
# Date: 2024-09-16, Period: 3, Course: Communications
# Date: 2024-09-17, Period: 1, Course: FinFun
# Date: 2024-09-17, Period: 2, Course: DMA
# Date: 2024-09-17, Period: 3, Course: FinFun
# Date: 2024-09-18, Period: 1, Course: FinFun
# Date: 2024-09-18, Period: 2, Course: DMA
# Date: 2024-09-18, Period: 3, Course: Communications
# Date: 2024-09-19, Period: 1, Course: FinFun
# Date: 2024-09-19, Period: 3, Course: Finance
# Date: 2024-09-20, Period: 1, Course: CME
# Date: 2024-09-20, Period: 2, Course: Finance
# Date: 2024-09-20, Period: 3, Course: SH
# Date: 2024-09-23, Period: 1, Course: LPO
# Date: 2024-09-23, Period: 2, Course: Communications
# Date: 2024-09-23, Period: 3, Course: FinFun
# Date: 2024-09-24, Period: 1, Course: DMA
# Date: 2024-09-24, Period: 2, Course: FinFun
# Date: 2024-09-24, Period: 3, Course: DMA
# Date: 2024-09-25, Period: 1, Course: DMA
# Date: 2024-09-25, Period: 2, Course: Finance
# Date: 2024-09-26, Period: 1, Course: FinFun
# Date: 2024-09-26, Period: 2, Course: Finance
# Date: 2024-09-26, Period: 3, Course: Finance
# Date: 2024-09-27, Period: 1, Course: Communications
# Date: 2024-09-27, Period: 2, Course: LPO
# Date: 2024-09-27, Period: 3, Course: Finance
# Date: 2024-10-01, Period: 1, Course: LPO
# Date: 2024-10-01, Period: 2, Course: Finance
# Date: 2024-10-01, Period: 3, Course: LPO
# Date: 2024-10-02, Period: 1, Course: LPO
# Date: 2024-10-02, Period: 2, Course: DMA
# Date: 2024-10-02, Period: 3, Course: LPO
# Date: 2024-10-03, Period: 1, Course: Finance
# Date: 2024-10-03, Period: 2, Course: Communications
# Date: 2024-10-03, Period: 3, Course: DMA
# Date: 2024-10-07, Period: 1, Course: DMA
# Date: 2024-10-07, Period: 2, Course: Finance
# Date: 2024-10-07, Period: 3, Course: Finance
# Date: 2024-10-08, Period: 1, Course: LPO
# Date: 2024-10-08, Period: 2, Course: DMA
# Date: 2024-10-08, Period: 3, Course: FinFun
# Date: 2024-10-09, Period: 1, Course: Finance
# Date: 2024-10-09, Period: 2, Course: DMA
# Date: 2024-10-09, Period: 3, Course: FinFun
# Date: 2024-10-10, Period: 1, Course: Communications
# Date: 2024-10-10, Period: 2, Course: LPO
# Date: 2024-10-10, Period: 3, Course: Finance
# Date: 2024-10-11, Period: 1, Course: LPO
# Date: 2024-10-11, Period: 2, Course: Communications
# Date: 2024-10-21, Period: 1, Course: DMA
# Date: 2024-10-21, Period: 2, Course: Finance
# Date: 2024-10-21, Period: 3, Course: Finance
# Date: 2024-10-28, Period: 1, Course: DMA
# Date: 2024-10-28, Period: 2, Course: FinFun
# Date: 2024-10-29, Period: 1, Course: SH
# Date: 2024-10-29, Period: 2, Course: FinFun
# Date: 2024-10-29, Period: 3, Course: CME
# Date: 2024-11-04, Period: 1, Course: LPO
# Date: 2024-11-04, Period: 2, Course: Communications
# Date: 2024-11-05, Period: 1, Course: Communications
# Date: 2024-11-05, Period: 2, Course: FinFun
# Date: 2024-11-05, Period: 3, Course: FinFun
# Date: 2024-11-06, Period: 1, Course: FinFun
# Date: 2024-11-06, Period: 2, Course: Finance
# Date: 2024-11-06, Period: 3, Course: Finance
# Date: 2024-11-07, Period: 2, Course: LPO
# Date: 2024-11-07, Period: 3, Course: DMA
# Date: 2024-11-08, Period: 1, Course: DMA
# Date: 2024-11-08, Period: 2, Course: Finance
# Date: 2024-11-08, Period: 3, Course: LPO
# Date: 2024-11-11, Period: 1, Course: DMA
# Date: 2024-11-11, Period: 2, Course: LPO
# Date: 2024-11-11, Period: 3, Course: Communications
# Date: 2024-11-12, Period: 1, Course: Communications
# Date: 2024-11-12, Period: 2, Course: Finance
# Date: 2024-11-12, Period: 3, Course: Communications
# Date: 2024-11-13, Period: 1, Course: Communications
# Date: 2024-11-13, Period: 2, Course: Finance
# Date: 2024-11-13, Period: 3, Course: Communications
# Date: 2024-11-14, Period: 1, Course: Communications
# Date: 2024-11-14, Period: 3, Course: FinFun
# Date: 2024-11-15, Period: 1, Course: Communications
# Date: 2024-11-15, Period: 2, Course: DMA
# Date: 2024-11-15, Period: 3, Course: CME
# Date: 2024-11-18, Period: 1, Course: LPO
# Date: 2024-11-18, Period: 2, Course: Communications
# Date: 2024-11-19, Period: 1, Course: Communications
# Date: 2024-11-19, Period: 2, Course: LPO
# Date: 2024-11-19, Period: 3, Course: Finance
# Date: 2024-11-20, Period: 1, Course: LPO
# Date: 2024-11-20, Period: 2, Course: Communications
# Date: 2024-11-25, Period: 1, Course: FinFun
# Date: 2024-11-25, Period: 2, Course: DMA
# Date: 2024-11-25, Period: 3, Course: DMA
# Date: 2024-11-26, Period: 1, Course: CME
# Date: 2024-11-26, Period: 2, Course: Finance
# Date: 2024-11-26, Period: 3, Course: LPO
# Date: 2024-11-27, Period: 1, Course: FinFun
# Date: 2024-11-27, Period: 2, Course: Finance
# Date: 2024-11-27, Period: 3, Course: FinFun
# Date: 2024-11-28, Period: 2, Course: FinFun
# Date: 2024-11-28, Period: 3, Course: Finance
# Date: 2024-11-29, Period: 1, Course: LPO
# Date: 2024-11-29, Period: 2, Course: Finance
# Date: 2024-11-29, Period: 3, Course: Finance
# Date: 2024-12-03, Period: 1, Course: FinFun
# Date: 2024-12-03, Period: 2, Course: LPO
# Date: 2024-12-03, Period: 3, Course: LPO
# Date: 2024-12-04, Period: 1, Course: FinFun
# Date: 2024-12-04, Period: 2, Course: Communications
# Date: 2024-12-04, Period: 3, Course: LPO
# Date: 2024-12-05, Period: 1, Course: Communications
# Date: 2024-12-05, Period: 2, Course: DMA
# Date: 2024-12-05, Period: 3, Course: LPO
# Date: 2024-12-06, Period: 1, Course: Communications
# Date: 2024-12-06, Period: 3, Course: Communications
#
# Schedule for Section 8:
# Date: 2024-09-09, Period: 1, Course: FinFun
# Date: 2024-09-09, Period: 2, Course: SH
# Date: 2024-09-09, Period: 3, Course: DMA
# Date: 2024-09-10, Period: 2, Course: Communications
# Date: 2024-09-10, Period: 3, Course: DMA
# Date: 2024-09-11, Period: 1, Course: CME
# Date: 2024-09-11, Period: 2, Course: FinFun
# Date: 2024-09-11, Period: 3, Course: Finance
# Date: 2024-09-12, Period: 1, Course: Finance
# Date: 2024-09-12, Period: 2, Course: LPO
# Date: 2024-09-12, Period: 3, Course: DMA
# Date: 2024-09-13, Period: 1, Course: LPO
# Date: 2024-09-13, Period: 2, Course: Finance
# Date: 2024-09-16, Period: 1, Course: FinFun
# Date: 2024-09-16, Period: 2, Course: LPO
# Date: 2024-09-16, Period: 3, Course: Finance
# Date: 2024-09-17, Period: 1, Course: Finance
# Date: 2024-09-17, Period: 2, Course: LPO
# Date: 2024-09-17, Period: 3, Course: LPO
# Date: 2024-09-18, Period: 1, Course: DMA
# Date: 2024-09-18, Period: 2, Course: Communications
# Date: 2024-09-18, Period: 3, Course: DMA
# Date: 2024-09-19, Period: 1, Course: Communications
# Date: 2024-09-19, Period: 2, Course: Finance
# Date: 2024-09-19, Period: 3, Course: DMA
# Date: 2024-09-20, Period: 1, Course: CME
# Date: 2024-09-20, Period: 2, Course: DMA
# Date: 2024-09-20, Period: 3, Course: Communications
# Date: 2024-09-23, Period: 1, Course: FinFun
# Date: 2024-09-24, Period: 1, Course: FinFun
# Date: 2024-09-24, Period: 2, Course: LPO
# Date: 2024-09-24, Period: 3, Course: Finance
# Date: 2024-09-25, Period: 1, Course: Finance
# Date: 2024-09-25, Period: 2, Course: DMA
# Date: 2024-09-26, Period: 1, Course: LPO
# Date: 2024-09-26, Period: 2, Course: DMA
# Date: 2024-09-26, Period: 3, Course: LPO
# Date: 2024-09-27, Period: 1, Course: Finance
# Date: 2024-09-27, Period: 2, Course: DMA
# Date: 2024-09-27, Period: 3, Course: Communications
# Date: 2024-10-01, Period: 1, Course: FinFun
# Date: 2024-10-01, Period: 2, Course: FinFun
# Date: 2024-10-01, Period: 3, Course: Finance
# Date: 2024-10-02, Period: 1, Course: DMA
# Date: 2024-10-02, Period: 2, Course: FinFun
# Date: 2024-10-02, Period: 3, Course: Communications
# Date: 2024-10-03, Period: 1, Course: LPO
# Date: 2024-10-03, Period: 2, Course: LPO
# Date: 2024-10-03, Period: 3, Course: Communications
# Date: 2024-10-07, Period: 1, Course: Communications
# Date: 2024-10-07, Period: 2, Course: LPO
# Date: 2024-10-07, Period: 3, Course: FinFun
# Date: 2024-10-08, Period: 1, Course: DMA
# Date: 2024-10-08, Period: 2, Course: Finance
# Date: 2024-10-08, Period: 3, Course: Finance
# Date: 2024-10-09, Period: 1, Course: Communications
# Date: 2024-10-09, Period: 2, Course: LPO
# Date: 2024-10-09, Period: 3, Course: DMA
# Date: 2024-10-10, Period: 1, Course: DMA
# Date: 2024-10-10, Period: 2, Course: FinFun
# Date: 2024-10-10, Period: 3, Course: Communications
# Date: 2024-10-11, Period: 1, Course: Finance
# Date: 2024-10-11, Period: 2, Course: Finance
# Date: 2024-10-11, Period: 3, Course: LPO
# Date: 2024-10-21, Period: 1, Course: Finance
# Date: 2024-10-21, Period: 2, Course: LPO
# Date: 2024-10-21, Period: 3, Course: Communications
# Date: 2024-10-28, Period: 1, Course: LPO
# Date: 2024-10-28, Period: 2, Course: DMA
# Date: 2024-10-28, Period: 3, Course: SH
# Date: 2024-10-29, Period: 2, Course: Finance
# Date: 2024-10-29, Period: 3, Course: CME
# Date: 2024-11-04, Period: 1, Course: Communications
# Date: 2024-11-04, Period: 2, Course: LPO
# Date: 2024-11-04, Period: 3, Course: Communications
# Date: 2024-11-05, Period: 1, Course: FinFun
# Date: 2024-11-05, Period: 2, Course: Communications
# Date: 2024-11-05, Period: 3, Course: Communications
# Date: 2024-11-06, Period: 1, Course: Finance
# Date: 2024-11-06, Period: 2, Course: DMA
# Date: 2024-11-06, Period: 3, Course: FinFun
# Date: 2024-11-07, Period: 1, Course: Communications
# Date: 2024-11-07, Period: 2, Course: DMA
# Date: 2024-11-07, Period: 3, Course: FinFun
# Date: 2024-11-08, Period: 1, Course: FinFun
# Date: 2024-11-08, Period: 2, Course: FinFun
# Date: 2024-11-08, Period: 3, Course: Communications
# Date: 2024-11-11, Period: 1, Course: FinFun
# Date: 2024-11-11, Period: 2, Course: FinFun
# Date: 2024-11-11, Period: 3, Course: DMA
# Date: 2024-11-12, Period: 1, Course: LPO
# Date: 2024-11-12, Period: 2, Course: LPO
# Date: 2024-11-12, Period: 3, Course: Finance
# Date: 2024-11-13, Period: 1, Course: Finance
# Date: 2024-11-13, Period: 2, Course: DMA
# Date: 2024-11-13, Period: 3, Course: FinFun
# Date: 2024-11-14, Period: 1, Course: FinFun
# Date: 2024-11-14, Period: 3, Course: LPO
# Date: 2024-11-15, Period: 1, Course: Finance
# Date: 2024-11-15, Period: 2, Course: FinFun
# Date: 2024-11-15, Period: 3, Course: CME
# Date: 2024-11-18, Period: 2, Course: FinFun
# Date: 2024-11-19, Period: 1, Course: Finance
# Date: 2024-11-19, Period: 2, Course: DMA
# Date: 2024-11-19, Period: 3, Course: Communications
# Date: 2024-11-20, Period: 2, Course: Finance
# Date: 2024-11-25, Period: 1, Course: DMA
# Date: 2024-11-25, Period: 2, Course: LPO
# Date: 2024-11-25, Period: 3, Course: Communications
# Date: 2024-11-26, Period: 1, Course: CME
# Date: 2024-11-26, Period: 2, Course: Communications
# Date: 2024-11-26, Period: 3, Course: FinFun
# Date: 2024-11-27, Period: 1, Course: Finance
# Date: 2024-11-27, Period: 2, Course: LPO
# Date: 2024-11-27, Period: 3, Course: DMA
# Date: 2024-11-28, Period: 1, Course: LPO
# Date: 2024-11-28, Period: 2, Course: DMA
# Date: 2024-11-28, Period: 3, Course: Communications
# Date: 2024-11-29, Period: 3, Course: Communications
# Date: 2024-12-03, Period: 1, Course: DMA
# Date: 2024-12-03, Period: 2, Course: FinFun
# Date: 2024-12-03, Period: 3, Course: Communications
# Date: 2024-12-04, Period: 1, Course: Communications
# Date: 2024-12-04, Period: 2, Course: LPO
# Date: 2024-12-04, Period: 3, Course: FinFun
# Date: 2024-12-05, Period: 1, Course: LPO
# Date: 2024-12-05, Period: 2, Course: FinFun
# Date: 2024-12-05, Period: 3, Course: Communications
# Date: 2024-12-06, Period: 1, Course: Finance
# Date: 2024-12-06, Period: 2, Course: LPO
# Date: 2024-12-06, Period: 3, Course: Finance
#
# Schedule for Section 9:
# Date: 2024-09-09, Period: 1, Course: Communications
# Date: 2024-09-09, Period: 2, Course: Finance
# Date: 2024-09-09, Period: 3, Course: DMA
# Date: 2024-09-10, Period: 1, Course: LPO
# Date: 2024-09-10, Period: 2, Course: DMA
# Date: 2024-09-10, Period: 3, Course: FinFun
# Date: 2024-09-11, Period: 1, Course: CME
# Date: 2024-09-11, Period: 2, Course: Communications
# Date: 2024-09-11, Period: 3, Course: LPO
# Date: 2024-09-12, Period: 1, Course: SH
# Date: 2024-09-12, Period: 2, Course: Finance
# Date: 2024-09-12, Period: 3, Course: LPO
# Date: 2024-09-13, Period: 1, Course: DMA
# Date: 2024-09-13, Period: 3, Course: DMA
# Date: 2024-09-16, Period: 1, Course: DMA
# Date: 2024-09-16, Period: 2, Course: Communications
# Date: 2024-09-16, Period: 3, Course: LPO
# Date: 2024-09-17, Period: 1, Course: FinFun
# Date: 2024-09-17, Period: 2, Course: Communications
# Date: 2024-09-17, Period: 3, Course: DMA
# Date: 2024-09-18, Period: 1, Course: LPO
# Date: 2024-09-18, Period: 2, Course: Finance
# Date: 2024-09-18, Period: 3, Course: Communications
# Date: 2024-09-19, Period: 1, Course: Finance
# Date: 2024-09-19, Period: 2, Course: Communications
# Date: 2024-09-19, Period: 3, Course: DMA
# Date: 2024-09-20, Period: 1, Course: CME
# Date: 2024-09-20, Period: 2, Course: FinFun
# Date: 2024-09-20, Period: 3, Course: LPO
# Date: 2024-09-23, Period: 2, Course: Communications
# Date: 2024-09-23, Period: 3, Course: LPO
# Date: 2024-09-24, Period: 1, Course: Finance
# Date: 2024-09-24, Period: 2, Course: Finance
# Date: 2024-09-24, Period: 3, Course: Communications
# Date: 2024-09-25, Period: 1, Course: DMA
# Date: 2024-09-25, Period: 2, Course: FinFun
# Date: 2024-09-26, Period: 1, Course: Communications
# Date: 2024-09-27, Period: 1, Course: Communications
# Date: 2024-09-27, Period: 2, Course: LPO
# Date: 2024-09-27, Period: 3, Course: FinFun
# Date: 2024-10-01, Period: 1, Course: DMA
# Date: 2024-10-01, Period: 2, Course: LPO
# Date: 2024-10-02, Period: 1, Course: LPO
# Date: 2024-10-02, Period: 2, Course: LPO
# Date: 2024-10-02, Period: 3, Course: DMA
# Date: 2024-10-03, Period: 1, Course: FinFun
# Date: 2024-10-03, Period: 2, Course: Communications
# Date: 2024-10-03, Period: 3, Course: LPO
# Date: 2024-10-07, Period: 2, Course: Communications
# Date: 2024-10-07, Period: 3, Course: Communications
# Date: 2024-10-08, Period: 1, Course: LPO
# Date: 2024-10-08, Period: 2, Course: Finance
# Date: 2024-10-08, Period: 3, Course: FinFun
# Date: 2024-10-09, Period: 1, Course: Finance
# Date: 2024-10-09, Period: 2, Course: Finance
# Date: 2024-10-09, Period: 3, Course: FinFun
# Date: 2024-10-10, Period: 1, Course: FinFun
# Date: 2024-10-10, Period: 2, Course: Communications
# Date: 2024-10-10, Period: 3, Course: DMA
# Date: 2024-10-11, Period: 1, Course: LPO
# Date: 2024-10-11, Period: 2, Course: Finance
# Date: 2024-10-11, Period: 3, Course: LPO
# Date: 2024-10-21, Period: 1, Course: Finance
# Date: 2024-10-21, Period: 2, Course: Communications
# Date: 2024-10-21, Period: 3, Course: Communications
# Date: 2024-10-28, Period: 1, Course: LPO
# Date: 2024-10-28, Period: 2, Course: Communications
# Date: 2024-10-29, Period: 1, Course: SH
# Date: 2024-10-29, Period: 2, Course: LPO
# Date: 2024-10-29, Period: 3, Course: CME
# Date: 2024-11-04, Period: 1, Course: Finance
# Date: 2024-11-04, Period: 2, Course: DMA
# Date: 2024-11-04, Period: 3, Course: Finance
# Date: 2024-11-05, Period: 1, Course: Communications
# Date: 2024-11-05, Period: 2, Course: FinFun
# Date: 2024-11-05, Period: 3, Course: DMA
# Date: 2024-11-06, Period: 1, Course: DMA
# Date: 2024-11-06, Period: 2, Course: FinFun
# Date: 2024-11-06, Period: 3, Course: Communications
# Date: 2024-11-07, Period: 1, Course: DMA
# Date: 2024-11-07, Period: 2, Course: DMA
# Date: 2024-11-07, Period: 3, Course: DMA
# Date: 2024-11-08, Period: 1, Course: LPO
# Date: 2024-11-08, Period: 2, Course: LPO
# Date: 2024-11-08, Period: 3, Course: Finance
# Date: 2024-11-11, Period: 1, Course: Finance
# Date: 2024-11-11, Period: 2, Course: FinFun
# Date: 2024-11-11, Period: 3, Course: FinFun
# Date: 2024-11-12, Period: 1, Course: FinFun
# Date: 2024-11-12, Period: 2, Course: LPO
# Date: 2024-11-12, Period: 3, Course: Finance
# Date: 2024-11-13, Period: 1, Course: LPO
# Date: 2024-11-13, Period: 2, Course: Communications
# Date: 2024-11-13, Period: 3, Course: FinFun
# Date: 2024-11-14, Period: 1, Course: LPO
# Date: 2024-11-14, Period: 3, Course: DMA
# Date: 2024-11-15, Period: 1, Course: LPO
# Date: 2024-11-15, Period: 2, Course: Finance
# Date: 2024-11-15, Period: 3, Course: CME
# Date: 2024-11-18, Period: 1, Course: FinFun
# Date: 2024-11-18, Period: 2, Course: Communications
# Date: 2024-11-19, Period: 1, Course: FinFun
# Date: 2024-11-19, Period: 2, Course: Finance
# Date: 2024-11-19, Period: 3, Course: LPO
# Date: 2024-11-20, Period: 1, Course: DMA
# Date: 2024-11-20, Period: 2, Course: Communications
# Date: 2024-11-25, Period: 1, Course: FinFun
# Date: 2024-11-25, Period: 2, Course: FinFun
# Date: 2024-11-25, Period: 3, Course: FinFun
# Date: 2024-11-26, Period: 1, Course: CME
# Date: 2024-11-26, Period: 2, Course: FinFun
# Date: 2024-11-26, Period: 3, Course: Finance
# Date: 2024-11-27, Period: 1, Course: FinFun
# Date: 2024-11-27, Period: 2, Course: Communications
# Date: 2024-11-27, Period: 3, Course: FinFun
# Date: 2024-11-28, Period: 1, Course: Finance
# Date: 2024-11-28, Period: 2, Course: Communications
# Date: 2024-11-29, Period: 1, Course: DMA
# Date: 2024-11-29, Period: 3, Course: DMA
# Date: 2024-12-03, Period: 1, Course: LPO
# Date: 2024-12-03, Period: 2, Course: Finance
# Date: 2024-12-03, Period: 3, Course: Communications
# Date: 2024-12-04, Period: 1, Course: Finance
# Date: 2024-12-04, Period: 2, Course: Finance
# Date: 2024-12-04, Period: 3, Course: DMA
# Date: 2024-12-05, Period: 1, Course: Finance
# Date: 2024-12-05, Period: 2, Course: Finance
# Date: 2024-12-05, Period: 3, Course: DMA
# Date: 2024-12-06, Period: 1, Course: DMA
# Date: 2024-12-06, Period: 2, Course: FinFun
# Date: 2024-12-06, Period: 3, Course: FinFun
#
# Schedule for Section 10:
# Date: 2024-09-09, Period: 1, Course: FinFun
# Date: 2024-09-09, Period: 2, Course: FinFun
# Date: 2024-09-09, Period: 3, Course: Finance
# Date: 2024-09-10, Period: 1, Course: FinFun
# Date: 2024-09-10, Period: 2, Course: LPO
# Date: 2024-09-10, Period: 3, Course: DMA
# Date: 2024-09-11, Period: 1, Course: CME
# Date: 2024-09-11, Period: 2, Course: FinFun
# Date: 2024-09-11, Period: 3, Course: DMA
# Date: 2024-09-12, Period: 1, Course: FinFun
# Date: 2024-09-12, Period: 2, Course: Communications
# Date: 2024-09-12, Period: 3, Course: Finance
# Date: 2024-09-13, Period: 1, Course: Communications
# Date: 2024-09-13, Period: 2, Course: FinFun
# Date: 2024-09-13, Period: 3, Course: FinFun
# Date: 2024-09-16, Period: 1, Course: Communications
# Date: 2024-09-16, Period: 2, Course: Finance
# Date: 2024-09-16, Period: 3, Course: FinFun
# Date: 2024-09-17, Period: 1, Course: SH
# Date: 2024-09-17, Period: 2, Course: LPO
# Date: 2024-09-17, Period: 3, Course: Finance
# Date: 2024-09-18, Period: 1, Course: DMA
# Date: 2024-09-18, Period: 2, Course: Communications
# Date: 2024-09-19, Period: 1, Course: FinFun
# Date: 2024-09-19, Period: 2, Course: Finance
# Date: 2024-09-19, Period: 3, Course: FinFun
# Date: 2024-09-20, Period: 1, Course: CME
# Date: 2024-09-20, Period: 2, Course: Finance
# Date: 2024-09-20, Period: 3, Course: DMA
# Date: 2024-09-23, Period: 1, Course: DMA
# Date: 2024-09-23, Period: 2, Course: Finance
# Date: 2024-09-23, Period: 3, Course: Communications
# Date: 2024-09-24, Period: 1, Course: LPO
# Date: 2024-09-24, Period: 2, Course: FinFun
# Date: 2024-09-24, Period: 3, Course: Finance
# Date: 2024-09-25, Period: 1, Course: Finance
# Date: 2024-09-25, Period: 2, Course: Communications
# Date: 2024-09-26, Period: 1, Course: LPO
# Date: 2024-09-26, Period: 2, Course: DMA
# Date: 2024-09-26, Period: 3, Course: DMA
# Date: 2024-09-27, Period: 1, Course: LPO
# Date: 2024-09-27, Period: 2, Course: Communications
# Date: 2024-09-27, Period: 3, Course: Finance
# Date: 2024-10-01, Period: 1, Course: FinFun
# Date: 2024-10-01, Period: 2, Course: DMA
# Date: 2024-10-01, Period: 3, Course: LPO
# Date: 2024-10-02, Period: 1, Course: Communications
# Date: 2024-10-02, Period: 2, Course: Finance
# Date: 2024-10-02, Period: 3, Course: Communications
# Date: 2024-10-03, Period: 1, Course: Communications
# Date: 2024-10-03, Period: 2, Course: LPO
# Date: 2024-10-03, Period: 3, Course: Communications
# Date: 2024-10-07, Period: 1, Course: Finance
# Date: 2024-10-07, Period: 2, Course: FinFun
# Date: 2024-10-07, Period: 3, Course: LPO
# Date: 2024-10-08, Period: 1, Course: FinFun
# Date: 2024-10-08, Period: 2, Course: Communications
# Date: 2024-10-09, Period: 1, Course: DMA
# Date: 2024-10-09, Period: 2, Course: LPO
# Date: 2024-10-09, Period: 3, Course: LPO
# Date: 2024-10-10, Period: 2, Course: LPO
# Date: 2024-10-10, Period: 3, Course: FinFun
# Date: 2024-10-11, Period: 1, Course: FinFun
# Date: 2024-10-11, Period: 2, Course: FinFun
# Date: 2024-10-21, Period: 1, Course: DMA
# Date: 2024-10-21, Period: 2, Course: LPO
# Date: 2024-10-21, Period: 3, Course: LPO
# Date: 2024-10-28, Period: 1, Course: Finance
# Date: 2024-10-28, Period: 2, Course: FinFun
# Date: 2024-10-28, Period: 3, Course: SH
# Date: 2024-10-29, Period: 1, Course: Finance
# Date: 2024-10-29, Period: 2, Course: Finance
# Date: 2024-10-29, Period: 3, Course: CME
# Date: 2024-11-04, Period: 2, Course: Finance
# Date: 2024-11-04, Period: 3, Course: Communications
# Date: 2024-11-05, Period: 1, Course: DMA
# Date: 2024-11-05, Period: 2, Course: LPO
# Date: 2024-11-05, Period: 3, Course: FinFun
# Date: 2024-11-06, Period: 1, Course: FinFun
# Date: 2024-11-06, Period: 2, Course: Communications
# Date: 2024-11-06, Period: 3, Course: Finance
# Date: 2024-11-07, Period: 1, Course: LPO
# Date: 2024-11-07, Period: 2, Course: Finance
# Date: 2024-11-07, Period: 3, Course: Communications
# Date: 2024-11-08, Period: 1, Course: DMA
# Date: 2024-11-08, Period: 2, Course: Communications
# Date: 2024-11-08, Period: 3, Course: FinFun
# Date: 2024-11-11, Period: 1, Course: Communications
# Date: 2024-11-11, Period: 3, Course: Communications
# Date: 2024-11-12, Period: 1, Course: LPO
# Date: 2024-11-12, Period: 2, Course: DMA
# Date: 2024-11-12, Period: 3, Course: LPO
# Date: 2024-11-13, Period: 1, Course: Finance
# Date: 2024-11-13, Period: 2, Course: DMA
# Date: 2024-11-13, Period: 3, Course: DMA
# Date: 2024-11-14, Period: 1, Course: Finance
# Date: 2024-11-14, Period: 3, Course: LPO
# Date: 2024-11-15, Period: 1, Course: DMA
# Date: 2024-11-15, Period: 2, Course: Communications
# Date: 2024-11-15, Period: 3, Course: CME
# Date: 2024-11-18, Period: 1, Course: Communications
# Date: 2024-11-18, Period: 2, Course: DMA
# Date: 2024-11-19, Period: 1, Course: Finance
# Date: 2024-11-19, Period: 3, Course: DMA
# Date: 2024-11-20, Period: 1, Course: LPO
# Date: 2024-11-20, Period: 2, Course: FinFun
# Date: 2024-11-25, Period: 1, Course: DMA
# Date: 2024-11-25, Period: 3, Course: Finance
# Date: 2024-11-26, Period: 1, Course: CME
# Date: 2024-11-26, Period: 2, Course: Finance
# Date: 2024-11-26, Period: 3, Course: DMA
# Date: 2024-11-27, Period: 1, Course: DMA
# Date: 2024-11-27, Period: 2, Course: LPO
# Date: 2024-11-27, Period: 3, Course: Finance
# Date: 2024-11-28, Period: 1, Course: DMA
# Date: 2024-11-28, Period: 2, Course: FinFun
# Date: 2024-11-28, Period: 3, Course: LPO
# Date: 2024-11-29, Period: 1, Course: Communications
# Date: 2024-11-29, Period: 2, Course: DMA
# Date: 2024-11-29, Period: 3, Course: Communications
# Date: 2024-12-03, Period: 1, Course: Communications
# Date: 2024-12-03, Period: 3, Course: FinFun
# Date: 2024-12-04, Period: 1, Course: Communications
# Date: 2024-12-04, Period: 2, Course: Communications
# Date: 2024-12-04, Period: 3, Course: Finance
# Date: 2024-12-05, Period: 1, Course: LPO
# Date: 2024-12-05, Period: 2, Course: FinFun
# Date: 2024-12-05, Period: 3, Course: LPO
# Date: 2024-12-06, Period: 1, Course: LPO
# Date: 2024-12-06, Period: 2, Course: DMA
# Date: 2024-12-06, Period: 3, Course: LPO
